# %% [markdown]
# # Model Performance Summary for Twitter Sentiment Analysis

# %% [markdown]
# <table class="waffle" cellspacing="0" cellpadding="0">
#     <thead>
#       <tr>
#         <th class="row-header freezebar-origin-ltr"></th>
#         <th id="0C0" style="width:143px" class="column-headers-background">Model Name</th>
#         <th id="0C1" style="width:75px" class="column-headers-background">Neg Recall</th>
#         <th id="0C2" style="width:75px" class="column-headers-background">Neu Recall</th>
#         <th id="0C3" style="width:74px" class="column-headers-background">Pos Recall</th>
#         <th id="0C4" style="width:89px" class="column-headers-background">Macro Recall</th>
#         <th id="0C5" style="width:67px" class="column-headers-background">Accuracy</th>
#         <th id="0C6" style="width:85px" class="column-headers-background">Word Vector</th>
#         <th id="0C7" style="width:51px" class="column-headers-background">MIN DOC FREQ</th>
#         <th id="0C8" style="width:57px" class="column-headers-background">BI GRAMS</th>
#         <th id="0C9" style="width:36px" class="column-headers-background">tf/idf</th>
#         <th id="0C10" style="width:90px" class="column-headers-background">Word Emb</th>
#         <th id="0C11" style="width:54px" class="column-headers-background">SMOTE</th>
#         <th id="0C12" style="width:57px" class="column-headers-background">Lemma</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr style='height:20px;'>
#         <th id="0R1" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">2</div></th>
#         <td class="s1" dir="ltr">nb_model_06</td>
#         <td class="s2" dir="ltr">0.61</td>
#         <td class="s2" dir="ltr">0.56</td>
#         <td class="s2" dir="ltr">0.67</td>
#         <td class="s2" dir="ltr">0.61</td>
#         <td class="s2" dir="ltr">0.60</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3" dir="ltr"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3" dir="ltr">Y</td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R2" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">3</div></th>
#         <td class="s1" dir="ltr">nb_model_04</td>
#         <td class="s2" dir="ltr">0.60</td>
#         <td class="s2" dir="ltr">0.56</td>
#         <td class="s2" dir="ltr">0.66</td>
#         <td class="s2" dir="ltr">0.61</td>
#         <td class="s2" dir="ltr">0.60</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3" dir="ltr"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3" dir="ltr"></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R3" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">4</div></th>
#         <td class="s1" dir="ltr">nb_model_07</td>
#         <td class="s2" dir="ltr">0.65</td>
#         <td class="s2" dir="ltr">0.55</td>
#         <td class="s2" dir="ltr">0.62</td>
#         <td class="s2" dir="ltr">0.61</td>
#         <td class="s2" dir="ltr">0.58</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3" dir="ltr">Y</td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R4" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">5</div></th>
#         <td class="s1" dir="ltr">svm_model_02</td>
#         <td class="s2" dir="ltr">0.61</td>
#         <td class="s2" dir="ltr">0.62</td>
#         <td class="s2" dir="ltr">0.53</td>
#         <td class="s2" dir="ltr">0.59</td>
#         <td class="s2" dir="ltr">0.59</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R5" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">6</div></th>
#         <td class="s1" dir="ltr">svm_model_03</td>
#         <td class="s2" dir="ltr">0.60</td>
#         <td class="s2" dir="ltr">0.61</td>
#         <td class="s2" dir="ltr">0.51</td>
#         <td class="s2" dir="ltr">0.57</td>
#         <td class="s2" dir="ltr">0.57</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3" dir="ltr">Y</td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R6" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">7</div></th>
#         <td class="s1" dir="ltr">nb_model_01</td>
#         <td class="s2" dir="ltr">0.35</td>
#         <td class="s2" dir="ltr">0.71</td>
#         <td class="s2" dir="ltr">0.61</td>
#         <td class="s2" dir="ltr">0.56</td>
#         <td class="s2" dir="ltr">0.65</td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R7" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">8</div></th>
#         <td class="s1" dir="ltr">emb_model_02</td>
#         <td class="s2" dir="ltr">0.27</td>
#         <td class="s2" dir="ltr">0.78</td>
#         <td class="s2" dir="ltr">0.57</td>
#         <td class="s2" dir="ltr">0.54</td>
#         <td class="s2" dir="ltr">0.68</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R8" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">9</div></th>
#         <td class="s1 softmerge" dir="ltr">emb_model_02-lemma</td>
#         <td class="s2" dir="ltr">0.22</td>
#         <td class="s2" dir="ltr">0.78</td>
#         <td class="s2" dir="ltr">0.55</td>
#         <td class="s2" dir="ltr">0.52</td>
#         <td class="s2" dir="ltr">0.67</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R9" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">10</div></th>
#         <td class="s1" dir="ltr">emb_model_01</td>
#         <td class="s2" dir="ltr">0.25</td>
#         <td class="s2" dir="ltr">0.79</td>
#         <td class="s2" dir="ltr">0.51</td>
#         <td class="s2" dir="ltr">0.52</td>
#         <td class="s2" dir="ltr">0.66</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R10" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">11</div></th>
#         <td class="s1" dir="ltr">emb_model_03</td>
#         <td class="s2" dir="ltr">0.21</td>
#         <td class="s2" dir="ltr">0.81</td>
#         <td class="s2" dir="ltr">0.51</td>
#         <td class="s2" dir="ltr">0.51</td>
#         <td class="s2" dir="ltr">0.67</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R11" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">12</div></th>
#         <td class="s1" dir="ltr">nb_model_02</td>
#         <td class="s2" dir="ltr">0.23</td>
#         <td class="s2" dir="ltr">0.78</td>
#         <td class="s2" dir="ltr">0.53</td>
#         <td class="s2" dir="ltr">0.51</td>
#         <td class="s2" dir="ltr">0.66</td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R12" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">13</div></th>
#         <td class="s4" dir="ltr">Baseline - NB</td>
#         <td class="s5" dir="ltr">0.08</td>
#         <td class="s5" dir="ltr">0.78</td>
#         <td class="s5" dir="ltr">0.60</td>
#         <td class="s5" dir="ltr">0.49</td>
#         <td class="s5" dir="ltr">0.67</td>
#         <td class="s6" dir="ltr">Y</td>
#         <td class="s6"></td>
#         <td class="s6"></td>
#         <td class="s6"></td>
#         <td class="s6"></td>
#         <td class="s6"></td>
#         <td class="s6"></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R13" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">14</div></th>
#         <td class="s1" dir="ltr">emb_model_05</td>
#         <td class="s2" dir="ltr">0.06</td>
#         <td class="s2" dir="ltr">0.83</td>
#         <td class="s2" dir="ltr">0.51</td>
#         <td class="s2" dir="ltr">0.47</td>
#         <td class="s2" dir="ltr">0.68</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R14" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">15</div></th>
#         <td class="s1" dir="ltr">emb_model_04</td>
#         <td class="s2" dir="ltr">0.21</td>
#         <td class="s2" dir="ltr">0.77</td>
#         <td class="s2" dir="ltr">0.43</td>
#         <td class="s2" dir="ltr">0.47</td>
#         <td class="s2" dir="ltr">0.62</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R15" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">16</div></th>
#         <td class="s1 softmerge" dir="ltr">emb_model_04-lemma</td>
#         <td class="s2" dir="ltr">0.10</td>
#         <td class="s2" dir="ltr">0.80</td>
#         <td class="s2" dir="ltr">0.42</td>
#         <td class="s2" dir="ltr">0.44</td>
#         <td class="s2" dir="ltr">0.63</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R16" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">17</div></th>
#         <td class="s1" dir="ltr">nb_model_05</td>
#         <td class="s2" dir="ltr">0.03</td>
#         <td class="s2" dir="ltr">0.90</td>
#         <td class="s2" dir="ltr">0.36</td>
#         <td class="s2" dir="ltr">0.43</td>
#         <td class="s2" dir="ltr">0.67</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3" dir="ltr"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R17" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">18</div></th>
#         <td class="s1" dir="ltr">nb_model_03</td>
#         <td class="s2" dir="ltr">0.02</td>
#         <td class="s2" dir="ltr">0.90</td>
#         <td class="s2" dir="ltr">0.38</td>
#         <td class="s2" dir="ltr">0.43</td>
#         <td class="s2" dir="ltr">0.67</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R18" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">19</div></th>
#         <td class="s1" dir="ltr">svm_model_01</td>
#         <td class="s2" dir="ltr">0.03</td>
#         <td class="s2" dir="ltr">0.99</td>
#         <td class="s2" dir="ltr">0.16</td>
#         <td class="s2" dir="ltr">0.39</td>
#         <td class="s2" dir="ltr">0.65</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3" dir="ltr">Y</td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R19" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">20</div></th>
#         <td></td>
#         <td class="s1"></td>
#         <td class="s1"></td>
#         <td class="s1"></td>
#         <td class="s1"></td>
#         <td class="s1"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#         <td class="s3"></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R20" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">21</div></th>
#         <td></td>
#         <td class="s1"></td>
#         <td class="s1"></td>
#         <td class="s1"></td>
#         <td class="s1"></td>
#         <td class="s1"></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R21" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">22</div></th>
#         <td class="s7 softmerge" dir="ltr"><div class="softmerge-inner" style="width: 216px; left: -1px;">Basic Baseline Models</div></td>
#         <td class="s8"></td>
#         <td class="s8"></td>
#         <td class="s1"></td>
#         <td class="s1"></td>
#         <td class="s1"></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R22" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">23</div></th>
#         <td class="s1" dir="ltr">Pick Neutral</td>
#         <td class="s2" dir="ltr">0.00</td>
#         <td class="s2" dir="ltr">1.00</td>
#         <td class="s2" dir="ltr">0.00</td>
#         <td class="s2">0.33</td>
#         <td class="s2">0.60</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R23" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">24</div></th>
#         <td class="s1" dir="ltr">Pick Negative</td>
#         <td class="s2" dir="ltr">1.00</td>
#         <td class="s2" dir="ltr">0.00</td>
#         <td class="s2" dir="ltr">0.00</td>
#         <td class="s2">0.33</td>
#         <td class="s2">0.06</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R24" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">25</div></th>
#         <td class="s1" dir="ltr">Pick Positive</td>
#         <td class="s2" dir="ltr">0.00</td>
#         <td class="s2" dir="ltr">0.00</td>
#         <td class="s2" dir="ltr">1.00</td>
#         <td class="s2">0.33</td>
#         <td class="s2">0.33</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#       </tr>
#       <tr style='height:20px;'>
#         <th id="0R25" style="height: 20px;" class="row-headers-background"><div class="row-header-wrapper" style="line-height: 20px;">26</div></th>
#         <td class="s1" dir="ltr">Random</td>
#         <td class="s2">0.33</td>
#         <td class="s2">0.33</td>
#         <td class="s2">0.33</td>
#         <td class="s2">0.33</td>
#         <td class="s2">0.33</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#       </tr>
#     </tbody>
#   </table>

# %% [markdown]
# Eighteen models were run during the model selection process for Twitter sentiment analysis.  A baseline model was created that used a basic Naive Bayes Classifier with word vectors.  Basic Baseline Models are also included for reference that include picking one of the three classes or just random guessing.
#
# The models were judged by the following metrics in descending order of importance:
# * Macro Average Recall (*Macro Recall* above)
# * Balanced Recall for each of the three classes
# * Overall Accuracy
#
# The model that was selected as the best was a Naive Bayes Classifier that was tuned using Min Doc Frequency, used tf/idf, SMOTE oversampling and lemmatization.  It performed marginally better than the same model but without lemmatization.  Its performance metrics were:
# * Macro Average Recall 0.61
# * Per Class Recall
#     * Negative 0.61
#     * Neutral 0.56
#     * Positive 0.67
# * Accuracy 0.60
