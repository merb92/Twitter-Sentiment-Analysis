# %% [markdown]
# # Text Preprocessing for Twitter Sentiment Analysis

# %% [markdown]
# # Imports and Constants

# %%
import pandas as pd
import re
import nltk
from nltk.tokenize import TweetTokenizer

# %%
DATA_FILE_PATH = 'data/crowdflower-brands-and-product-emotions/data/'
CLEAN_DATA_FILE_NAME = 'clean_twitter_data.csv'

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv(DATA_FILE_PATH + CLEAN_DATA_FILE_NAME)

# %%
pd.set_option('display.max_colwidth', None)
df.head()
# Out:
#                                                                                                                                    tweet_text  \
# 0              .@mention I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @mention Know about @mention ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2                                                                @mention Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3                                                       @mention I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4           @mention great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#   emotion_in_tweet_is_directed_at  \
# 0                          iPhone
# 1              iPad or iPhone App
# 2                            iPad
# 3              iPad or iPhone App
# 4                          Google
#
#   is_there_an_emotion_directed_at_a_brand_or_product
# 0                                   Negative emotion
# 1                                   Positive emotion
# 2                                   Positive emotion
# 3                                   Negative emotion
# 4                                   Positive emotion

# %% [markdown]
# # Clean Data
#
# * lower case
# * remove punctuation except @ or # that are followed by characters
# * url links
# * {link}
# * @mention
# * &quot;
# *

# %%
df_clean = df

# %%
# lower case
df_clean.tweet_text = df_clean.tweet_text.str.lower()

# %%
df_clean.head(10)
# Out:
#                                                                                                                                    tweet_text  \
# 0              .@mention i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 1  @mention know about @mention ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at #sxsw
# 2                                                                @mention can not wait for #ipad 2 also. they should sale them down at #sxsw.
# 3                                                       @mention i hope this year's festival isn't as crashy as this year's iphone app. #sxsw
# 4           @mention great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
# 5     @mention new ipad apps for #speechtherapy and communication are showcased at the #sxsw conference http://ht.ly/49n4m #iear #edchat #asd
# 6  #sxsw is just starting, #ctia is around the corner and #googleio is only a hop skip and a jump from there, good time to be an #android fan
# 7                 beautifully smart and simple idea rt @mention @mention wrote about our #hollergram ipad app for #sxsw! http://bit.ly/ieavob
# 8                                                    counting down the days to #sxsw plus strong canadian dollar means stock up on apple gear
# 9                              excited to meet the @mention at #sxsw so i can show them my sprint galaxy s still running android 2.1.   #fail
#
#   emotion_in_tweet_is_directed_at  \
# 0                          iPhone
# 1              iPad or iPhone App
# 2                            iPad
# 3              iPad or iPhone App
# 4                          Google
# 5                             NaN
# 6                         Android
# 7              iPad or iPhone App
# 8                           Apple
# 9                         Android
#
#   is_there_an_emotion_directed_at_a_brand_or_product
# 0                                   Negative emotion
# 1                                   Positive emotion
# 2                                   Positive emotion
# 3                                   Negative emotion
# 4                                   Positive emotion
# 5                 No emotion toward brand or product
# 6                                   Positive emotion
# 7                                   Positive emotion
# 8                                   Positive emotion
# 9                                   Positive emotion

# %%
# url links
df_clean.tweet_text = df_clean.tweet_text.apply(lambda x: re.sub(r'https?:\/\/\S+', '', x))

# %%
df_clean.head(10)
# Out:
#                                                                                                                                    tweet_text  \
# 0              .@mention i have a 3g iphone. after 3 hrs tweeting at #rise_austin, it was dead!  i need to upgrade. plugin stations at #sxsw.
# 1  @mention know about @mention ? awesome ipad/iphone app that you'll likely appreciate for its design. also, they're giving free ts at #sxsw
# 2                                                                @mention can not wait for #ipad 2 also. they should sale them down at #sxsw.
# 3                                                       @mention i hope this year's festival isn't as crashy as this year's iphone app. #sxsw
# 4           @mention great stuff on fri #sxsw: marissa mayer (google), tim o'reilly (tech books/conferences) &amp; matt mullenweg (wordpress)
# 5                       @mention new ipad apps for #speechtherapy and communication are showcased at the #sxsw conference  #iear #edchat #asd
# 6  #sxsw is just starting, #ctia is around the corner and #googleio is only a hop skip and a jump from there, good time to be an #android fan
# 7                                     beautifully smart and simple idea rt @mention @mention wrote about our #hollergram ipad app for #sxsw!
# 8                                                    counting down the days to #sxsw plus strong canadian dollar means stock up on apple gear
# 9                              excited to meet the @mention at #sxsw so i can show them my sprint galaxy s still running android 2.1.   #fail
#
#   emotion_in_tweet_is_directed_at  \
# 0                          iPhone
# 1              iPad or iPhone App
# 2                            iPad
# 3              iPad or iPhone App
# 4                          Google
# 5                             NaN
# 6                         Android
# 7              iPad or iPhone App
# 8                           Apple
# 9                         Android
#
#   is_there_an_emotion_directed_at_a_brand_or_product
# 0                                   Negative emotion
# 1                                   Positive emotion
# 2                                   Positive emotion
# 3                                   Negative emotion
# 4                                   Positive emotion
# 5                 No emotion toward brand or product
# 6                                   Positive emotion
# 7                                   Positive emotion
# 8                                   Positive emotion
# 9                                   Positive emotion

# %%
# @mention
df_clean.tweet_text = df_clean.tweet_text.apply(lambda x: re.sub(r'@mention', '', x))

# %%
df_clean.tail(10)
# Out:
#                                                                                                                                              tweet_text  \
# 8559                                                               google says the future is all around you! (ie, location and such): {link} #sxsw #cnn
# 8560                                                                          google says the future is location, location, location: {link} #sxsw #cnn
# 8561          i've always used camera+ for my iphone b/c it has an image stabilizer mode. suggestions for an ipad cam app w/ same feature? #sxsw #sxswi
# 8562               google says: want to give a lightning talk to a #h4ckers audience at #sxsw tonight? email ben.mcgraw  gmail.com for a spot on stage.
# 8563                                                                 yup, but i don't have a third app yet. i'm on android, any suggestions? #sxsw cc:
# 8564                                                                                                                      ipad everywhere. #sxsw {link}
# 8565                              wave, buzz... rt  we interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 8566  google's zeiger, a physician never reported potential ae. yet fda relies on physicians. &quot;we're operating w/out data.&quot; #sxsw #health2dev
# 8567       some verizon iphone customers complained their time fell back an hour this weekend.  of course they were the new yorkers who attended #sxsw.
# 8568                                                          �ϡ�����_��ʋ�΋�ҋ�������⋁_��������_���rt  google tests ���check-in offers�۝ at #sxsw {link}
#
#      emotion_in_tweet_is_directed_at  \
# 8559                             NaN
# 8560                             NaN
# 8561              iPad or iPhone App
# 8562                             NaN
# 8563                             NaN
# 8564                            iPad
# 8565                             NaN
# 8566                             NaN
# 8567                             NaN
# 8568                             NaN
#
#      is_there_an_emotion_directed_at_a_brand_or_product
# 8559                 No emotion toward brand or product
# 8560                 No emotion toward brand or product
# 8561                                   Positive emotion
# 8562                 No emotion toward brand or product
# 8563                 No emotion toward brand or product
# 8564                                   Positive emotion
# 8565                 No emotion toward brand or product
# 8566                 No emotion toward brand or product
# 8567                 No emotion toward brand or product
# 8568                 No emotion toward brand or product

# %%
# {link}
df_clean.tweet_text = df_clean.tweet_text.apply(lambda x: re.sub(r'{link}', '', x))

# %%
df_clean.tail(10)
# Out:
#                                                                                                                                              tweet_text  \
# 8559                                                                     google says the future is all around you! (ie, location and such):  #sxsw #cnn
# 8560                                                                                google says the future is location, location, location:  #sxsw #cnn
# 8561          i've always used camera+ for my iphone b/c it has an image stabilizer mode. suggestions for an ipad cam app w/ same feature? #sxsw #sxswi
# 8562               google says: want to give a lightning talk to a #h4ckers audience at #sxsw tonight? email ben.mcgraw  gmail.com for a spot on stage.
# 8563                                                                 yup, but i don't have a third app yet. i'm on android, any suggestions? #sxsw cc:
# 8564                                                                                                                            ipad everywhere. #sxsw
# 8565                                    wave, buzz... rt  we interrupt your regularly scheduled #sxsw geek programming with big news   #google #circles
# 8566  google's zeiger, a physician never reported potential ae. yet fda relies on physicians. &quot;we're operating w/out data.&quot; #sxsw #health2dev
# 8567       some verizon iphone customers complained their time fell back an hour this weekend.  of course they were the new yorkers who attended #sxsw.
# 8568                                                                �ϡ�����_��ʋ�΋�ҋ�������⋁_��������_���rt  google tests ���check-in offers�۝ at #sxsw
#
#      emotion_in_tweet_is_directed_at  \
# 8559                             NaN
# 8560                             NaN
# 8561              iPad or iPhone App
# 8562                             NaN
# 8563                             NaN
# 8564                            iPad
# 8565                             NaN
# 8566                             NaN
# 8567                             NaN
# 8568                             NaN
#
#      is_there_an_emotion_directed_at_a_brand_or_product
# 8559                 No emotion toward brand or product
# 8560                 No emotion toward brand or product
# 8561                                   Positive emotion
# 8562                 No emotion toward brand or product
# 8563                 No emotion toward brand or product
# 8564                                   Positive emotion
# 8565                 No emotion toward brand or product
# 8566                 No emotion toward brand or product
# 8567                 No emotion toward brand or product
# 8568                 No emotion toward brand or product

# %%
# &quot;
df_clean.tweet_text = df_clean.tweet_text.apply(lambda x: re.sub(r'&quot;', '', x))

# %%
df_clean.iloc[10:20]
# Out:
#                                                                                                                           tweet_text  \
# 10                                    find &amp; start impromptu parties at #sxsw with   i can't wait til the android app comes out.
# 11                        foursquare ups the game, just in time for #sxsw  - still prefer  by far, best looking android app to date.
# 12                             gotta love this #sxsw google calendar featuring top parties/ show cases to check out.  rt  via  =&gt;
# 13                                                                                                      great #sxsw ipad app from :
# 14                                                                               haha, awesomely rad ipad app by   #hollergram #sxsw
# 15                                                              holler gram for ipad on the itunes app store -   (via _is_ken) #sxsw
# 16  i just noticed dst is coming this weekend. how many iphone users will be an hour late at sxsw come sunday morning? #sxsw #iphone
# 17                just added my #sxsw flights to . matching people on planes/airports. also downloaded the  iphone app, nicely done.
# 18                                          must have #sxsw app! rt : lovely review from forbes for our sxsw ipad app holler gram -
# 19                        need to buy an ipad2 while i'm in austin at #sxsw. not sure if i'll need to q up at an austin apple store?
#
#     emotion_in_tweet_is_directed_at  \
# 10                      Android App
# 11                      Android App
# 12  Other Google product or service
# 13               iPad or iPhone App
# 14               iPad or iPhone App
# 15                              NaN
# 16                           iPhone
# 17               iPad or iPhone App
# 18               iPad or iPhone App
# 19                             iPad
#
#    is_there_an_emotion_directed_at_a_brand_or_product
# 10                                   Positive emotion
# 11                                   Positive emotion
# 12                                   Positive emotion
# 13                                   Positive emotion
# 14                                   Positive emotion
# 15                 No emotion toward brand or product
# 16                                   Negative emotion
# 17                                   Positive emotion
# 18                                   Positive emotion
# 19                                   Positive emotion

# %%
# other &text; html chars
df_clean.tweet_text = df_clean.tweet_text.apply(lambda x: re.sub(r'&[a-z]+;', '', x))

# %%
# punctuation .,!?:'()~
# this does not take emoji type characters into account
df_clean.tweet_text = df_clean.tweet_text.apply(lambda x: re.sub(r"[\.,!\?~\+\*\%\$\@\[^`]", '', x))

# %%
# - when not touching a word, replace with a space since matching on whitespace
df_clean.tweet_text = df_clean.tweet_text.apply(lambda x: re.sub(r"\s+-+\s", ' ', x))

# %%
# [video]
df_clean.tweet_text = df_clean.tweet_text.apply(lambda x: re.sub(r"\[video\]", '', x))

# %%
# extra chars  [�嫉㋁⻋⣋⏋⋁ݍ܋܊ۼۄہ'ًԋҋϡύ_γʋǐġ~}|{]
df_clean.tweet_text = df_clean.tweet_text.apply(lambda x: re.sub(r"[�嫉㋁⻋⣋⏋⋁ݍ܋܊ۼۄہ'ًԋҋϡύ_γʋǐġ~}|{.'̤'̩\u038bξсԍـ\u06dd]", '', x))

# %%
df_clean.tweet_text = df_clean.tweet_text.apply(lambda x: re.sub("[" + chr(1762) + chr(1770) + "]", '', x))

# %%
# (\s[\$\(\%\*\+,\-/;=\?\@\[(\\\\)^`]\s)
df_clean.tweet_text = df_clean.tweet_text.apply(lambda x: re.sub(r"\s[\$\(\%\*\+,\-/;=\?\@\[(\\\\)^`]\s", '', x))

# %%
# numbers
df_clean.tweet_text = df_clean.tweet_text.apply(lambda x: re.sub(r"\d+", '', x))

# %%
#  \((?=[a-z])|(?<=[a-z])\)
# get rid of () that surround letters

# %%
df_clean.iloc[90:100]
# Out:
#                                                                                                    tweet_text  \
# 90                                                      wonder if  is putting tips from the  api #sxsw #suxsw
# 91                    xmas rt  shiny new    apps a new  book pop-up ipad  stores #sxsw is christmas for nerds
# 92  yai rt  new #ubersocial for #iphone now in the app store includes uberguide to #sxsw sponsored by (cont)
# 93                                                yes rt  hey   ive got another gem for you free  sxsw  #sxsw
# 94                                fast fun  future:  of google presenting at #sxsw on search local and mobile
# 95                          gsdm  googles industry party tonight see u there  #sxsw #austin #welivehere #gsdm
# 96               new buzz  google to launch major new social network called circles possibly today  rt  #sxsw
# 97           headline: #ipad  is the must-have gadget at #sxsw hmm i could have seen that one coming  #gadget
# 98                                   know that dataviz translates to satanic on an iphone im just sayin #sxsw
# 99           google launched checkins a month ago check ins are ok but check outs are the future #sxsw #bizzy
#
#    emotion_in_tweet_is_directed_at  \
# 90                             NaN
# 91                            iPad
# 92                          iPhone
# 93                             NaN
# 94                          Google
# 95                             NaN
# 96                             NaN
# 97                            iPad
# 98                             NaN
# 99                          Google
#
#    is_there_an_emotion_directed_at_a_brand_or_product
# 90                 No emotion toward brand or product
# 91                                   Positive emotion
# 92                                   Positive emotion
# 93                 No emotion toward brand or product
# 94                                   Positive emotion
# 95                 No emotion toward brand or product
# 96                 No emotion toward brand or product
# 97                                   Positive emotion
# 98                                   Negative emotion
# 99                                   Positive emotion

# %% [markdown]
# # Tokenize tweet_text

# %%
tknzr = TweetTokenizer()

# %%
df_clean['tokens'] = df_clean['tweet_text'].apply(tknzr.tokenize)

# %%
df_clean.iloc[40:50][['tweet_text', 'tokens']]
# Out:
#                                                                                                                tweet_text  \
# 40            hootsuite hootsuite mobile for #sxsw  updates for iphone blackberry  android: whether youre getting friend
# 41     hey #sxsw how long do you think it takes us to make an iphone case answer  using #zazzlesxsw and well make you one
# 42                                                        mashable the ipad  takes over sxsw video] #ipad #sxsw #gadgets
# 43              for i-pad rt  new #ubersocial for #iphone now in the app store includes uberguide to #sxsw sponsored by
# 44                                              hand-held hobo: drafthouse launches hobo with a shotgun iphone app #sxsw
# 45                                                      hooray rt  apple is opening a pop-up store in austin for #sxsw
# 46                                                  orly  google set to launch new social network #circles today at #sxsw
# 47                                                            wooooo  apple store downtown austin open til midnight #sxsw
# 48  khoi vinhsays conde nasts headlong rush into ipad publishing was a fundamental misunderstanding of the platform #sxsw
# 49                        help me forward this doc to all anonymous accounts techies ppl who can help us jam #libya #sxsw
#
#                                                                                                                                        tokens
# 40                  [hootsuite, hootsuite, mobile, for, #sxsw, updates, for, iphone, blackberry, android, :, whether, youre, getting, friend]
# 41  [hey, #sxsw, how, long, do, you, think, it, takes, us, to, make, an, iphone, case, answer, using, #zazzlesxsw, and, well, make, you, one]
# 42                                                                 [mashable, the, ipad, takes, over, sxsw, video, ], #ipad, #sxsw, #gadgets]
# 43                  [for, i-pad, rt, new, #ubersocial, for, #iphone, now, in, the, app, store, includes, uberguide, to, #sxsw, sponsored, by]
# 44                                                     [hand-held, hobo, :, drafthouse, launches, hobo, with, a, shotgun, iphone, app, #sxsw]
# 45                                                                 [hooray, rt, apple, is, opening, a, pop-up, store, in, austin, for, #sxsw]
# 46                                                          [orly, google, set, to, launch, new, social, network, #circles, today, at, #sxsw]
# 47                                                                       [wooooo, apple, store, downtown, austin, open, til, midnight, #sxsw]
# 48    [khoi, vinhsays, conde, nasts, headlong, rush, into, ipad, publishing, was, a, fundamental, misunderstanding, of, the, platform, #sxsw]
# 49                         [help, me, forward, this, doc, to, all, anonymous, accounts, techies, ppl, who, can, help, us, jam, #libya, #sxsw]

# %% [markdown]
# # Create Corpus

# %%
corpus = ' '.join(df_clean['tweet_text'])

# %%
corpus
# Out:
# ' i have a g iphone after  hrs tweeting at #riseaustin it was dead  i need to upgrade plugin stations at #sxsw  know about   awesome ipad/iphone app that youll likely appreciate for its design also theyre giving free ts at #sxsw  can not wait for #ipad  also they should sale them down at #sxsw  i hope this years festival isnt as crashy as this years iphone app #sxsw  great stuff on fri #sxsw: marissa mayer (google) tim oreilly (tech books/conferences)  matt mullenweg (wordpress)  new ipad apps for #speechtherapy and communication are showcased at the #sxsw conference  #iear #edchat #asd #sxsw is just starting #ctia is around the corner and #googleio is only a hop skip and a jump from there good time to be an #android fan beautifully smart and simple idea rt   wrote about our #hollergram ipad app for #sxsw  counting down the days to #sxsw plus strong canadian dollar means stock up on apple gear excited to meet the  at #sxsw so i can show them my sprint galaxy s still running android    #fail find  start impromptu parties at #sxsw with   i cant wait til the android app comes out foursquare ups the game just in time for #sxsw still prefer  by far best looking android app to date gotta love this #sxsw google calendar featuring top parties/ show cases to check out  rt  via  = great #sxsw ipad app from :  haha awesomely rad ipad app by   #hollergram #sxsw holler gram for ipad on the itunes app store   (via isken) #sxsw i just noticed dst is coming this weekend how many iphone users will be an hour late at sxsw come sunday morning #sxsw #iphone just added my #sxsw flights to  matching people on planes/airports also downloaded the  iphone app nicely done must have #sxsw app rt : lovely review from forbes for our sxsw ipad app holler gram  need to buy an ipad while im in austin at #sxsw not sure if ill need to q up at an austin apple store oh my god the #sxsw app for ipad is pure unadulterated awesome its easier to browse events on ipad than on the website okay this is really it: yay new  for #android app kthxbai #sxsw photo: just installed the #sxsw iphone app which is really nice  really enjoying the changes in gowalla  for android looking forward to seeing what else they  foursquare have up their sleeves at #sxsw rt : im looking forward to the #smcdallas pre #sxsw party wed and hoping ill win an #ipad resulting from my shameless promotion  #chevysmc rt haha awesomely rad ipad app by   #hollergram #sxsw (via ) someone started an #austin  group in google groups pre-#sxsw great idea the new #sq looks like it is going to rock update for iphone and android should push tonight  #sxsw #keepaustinweird they were right the   app on #android is sweeeeet nice job by the team there #sxsw very smart from  #hollergram ipad app for #sxsw  (may leave my vuvuzela at home now) you must have this app for your ipad if you are going to #sxsw  #hollergram attn: all  #sxsw frineds  register for #gdgtlive  and see cobra iradar for android  anyone at  #sxsw want to sell their old ipad anyone at  #sxsw who bought the new ipad want to sell their older ipad to me at #sxsw  oooh rt  google to launch major new social network called circles possibly today  the best  rt  ha first in line for #ipad at #sxsw pop-up apple store was an event planner #eventprofs #pcma #engage spin play a new concept in music discovery for your ipad from   spincom  #itunes #sxsw   false alarm: google circles not coming nowand probably not ever  #google #circles #social #sxsw vatornews google and apple force print media to evolve  #sxsw  great weather to greet you for #sxsw still need a sweater at nightapple putting up flash store downtown to sell ipad hootsuite hootsuite mobile for #sxsw  updates for iphone blackberry  android: whether youre getting friend  hey #sxsw how long do you think it takes us to make an iphone case answer  using #zazzlesxsw and well make you one mashable the ipad  takes over sxsw video] #ipad #sxsw #gadgets  for i-pad rt  new #ubersocial for #iphone now in the a ...

# %%
corpus_tokens = list(set(tknzr.tokenize(corpus)))
corpus_tokens
# Out:
# ['boss',
#  'crowleymore',
#  'setting',
#  'protecting',
#  'merchandise',
#  'waffling',
#  'following',
#  'submitted',
#  'crowdsourced',
#  'conveniently',
#  'smearing',
#  'headsets',
#  'hail',
#  '#itouru',
#  'allows',
#  'by',
#  'dies',
#  'skiers',
#  'now',
#  'bberry',
#  'latitude',
#  'frid',
#  'explode',
#  'wohooo',
#  'boy',
#  '#followback',
#  'livetapp',
#  'iron',
#  'glad',
#  'appealing',
#  '#ncaa',
#  'bings',
#  'comparison',
#  'mustachepox',
#  'my',
#  'various',
#  'ice',
#  '#technology',
#  'bitbop',
#  'account',
#  'promos',
#  'color',
#  'atleast',
#  'resume',
#  '#publicradio',
#  'overview',
#  'interview',
#  'swift',
#  'fav',
#  'pbs',
#  'democracy',
#  'fathom',
#  'ceo',
#  'impediment',
#  'awesome',
#  'garage',
#  'onmashto',
#  'destroyed',
#  'fetishism',
#  'brazils',
#  '#reward',
#  'groupedin',
#  'animation',
#  'jcpenney',
#  'streetan',
#  'earthquaketsunami',
#  'fascinating',
#  'cold',
#  'radisson',
#  'mocked',
#  'larry',
#  'twittering',
#  ':d',
#  'coworkers',
#  'jr',
#  'buggy',
#  'akqas',
#  'kudos',
#  'via',
#  '#mobilephotography',
#  'king',
#  'browsers',
#  'operating',
#  'riots',
#  'walls',
#  'rescue',
#  'gibson',
#  '#ecademy',
#  '#rackspace',
#  'action',
#  'been',
#  'forgo',
#  'shite',
#  'berry',
#  'pride',
#  '#quake',
#  'kara',
#  'conflict',
#  'sell',
#  'whiteboard',
#  ';',
#  'hahah',
#  'ossum',
#  'self-serve',
#  'visualize',
#  'down',
#  'city',
#  '#idontbelieve',
#  'iphoneblackberryandroid',
#  'hurt',
#  'foreshadowing',
#  '#loveher',
#  'sweeeet',
#  'off',
#  'grounlink',
#  'adoption',
#  'authorization',
#  'envisions',
#  'mini-store',
#  'bandcamp',
#  'added',
#  'behavior',
#  '#newyorkcity',
#  'errors',
#  'vidcamera',
#  'mq',
#  'denies',
#  'arw',
#  '#lolshow',
#  'readable',
#  'fancy',
#  'security',
#  'ultimate',
#  '#blogging',
#  'beautiful',
#  'headgive',
#  '#mashhash',
#  'pensei',
#  'dispenses',
#  'stole',
#  'downloadable',
#  'nor',
#  'relevancy',
#  'ate',
#  'rise',
#  'industry',
#  'fried',
#  'thingapple',
#  'grape',
#  'repressed',
#  'submit',
#  '#sxsw-ers',
#  'im',
#  'amiss',
#  'issued',
#  'cam',
#  '#calyp',
#  'shifting',
#  'values',
#  'pickup',
#  '#bavcid',
#  'cleanup',
#  'heard',
#  'overcrowded',
#  'reacquainted',
#  'exciting',
#  'cooler',
#  ':/',
#  'overuse',
#  'card',
#  '#wack',
#  'anticipation',
#  'airports',
#  'ridonkulous',
#  'ubuntu',
#  'doodle',
#  '#sxswcedar',
#  'nih',
#  'photoshop',
#  '#line',
#  '#xm',
#  'brocast',
#  'tandy',
#  'connecting',
#  '::',
#  'spend',
#  '#discovery',
#  'miles',
#  'teaching',
#  'plane',
#  'sponsored',
#  'cwebb',
#  '#techsmith',
#  '#hrs',
#  'confess',
#  'gotten',
#  'cellbots',
#  'cartridge',
#  'joinme',
#  'women',
#  'friend',
#  'twin-girls',
#  'upload',
#  'meaningful',
#  '#shocked',
#  'nutters',
#  'burner',
#  'multiplicity',
#  'ht',
#  '#ranking',
#  '#measure',
#  '#us',
#  '#techcrunch',
#  'ami',
#  'breakfast',
#  'confession',
#  'shiny',
#  'fiting',
#  'mexico',
#  '#love',
#  'lose',
#  'band',
#  'structures',
#  'prototyping',
#  'spasmatics',
#  '#tweetaholic',
#  'beta',
#  'owns',
#  'elevation',
#  'join',
#  'our',
#  'tokyo',
#  'startup',
#  'bose',
#  'devastating',
#  'ubergenius',
#  'yelp-style',
#  'putting',
#  'billboard',
#  'knew',
#  'positively',
#  'hooting',
#  'beyond',
#  'aftrnoon',
#  'superbia',
#  'making',
#  'recovery',
#  'e-mails',
#  'covr',
#  '#classicaudiencemisread',
#  '#notreally',
#  'fare',
#  'notsmell',
#  '#productive',
#  'evade',
#  'implement',
#  '#googledoodles',
#  'murphy',
#  'item',
#  'format',
#  'nu',
#  'lactation',
#  'umshini',
#  'applying',
#  'regrets',
#  'openbeta',
#  'playstation',
#  'bd',
#  'response',
#  'satesmancom',
#  'pops',
#  'jacinto',
#  'microsoft',
#  'galleries',
#  '#tc',
#  'frustrated',
#  'shipping',
#  'es',
#  'hs',
#  'awesomeness',
#  'mastered',
#  'activity',
#  'haystack',
#  'pukey',
#  '#amateurhour',
#  'cont',
#  'browse',
#  'djroe',
#  'i-phone',
#  'crossroads',
#  '#news',
#  'abuzz',
#  'qrank',
#  'u',
#  'mypov',
#  'ambassador',
#  'eff',
#  'comfortable',
#  'pager',
#  'serv',
#  'sweets',
#  'gecko',
#  'clark',
#  'org',
#  'knockout',
#  'shade',
#  'bloggable',
#  'buyers',
#  'rudy',
#  'combine',
#  'likes',
#  'task',
#  'solve',
#  'confirm',
#  'not-for-profits',
#  'cannot',
#  '#stevemartocci',
#  'mag',
#  'sxswsex',
#  'brilliant',
#  'punched',
#  'rough',
#  '#playsxsw',
#  'savvy',
#  'saw',
#  '#mindjet',
#  'bargain',
#  '#li',
#  'potgoogle',
#  'different',
#  'hackerspace',
#  'position',
#  'fame',
#  'juan',
#  'desktops',
#  'rolls',
#  'eminent',
#  'kingdom',
#  'rebecca',
#  'och',
#  'shindig',
#  'burn-b-q',
#  'attached',
#  'congratulations',
#  'madness',
#  'emerging',
#  'serendipitous',
#  'buys',
#  'flashmob',
#  'progression',
#  'guard',
#  '#wepartyhere',
#  'offchain',
#  'debuting',
#  'ora',
#  '#evaporation',
#  'factory',
#  '#integration',
#  'pdx',
#  'pigfucker',
#  '#techgood',
#  'garys',
#  'something',
#  'urs',
#  'force',
#  '#qrcode',
#  'd',
#  'dividends',
#  'xtra',
#  'made',
#  'weasel',
#  'guards',
#  'quick-contact',
#  'networks',
#  'plays',
#  'twitter',
#  'call',
#  'iterative',
#  'viporbit',
#  'stay',
#  'which',
#  'abound',
#  'confirmed',
#  '#ncbshow',
#  'tablet-optimized',
#  'makeup',
#  'lame',
#  'sweepstakes',
#  'premature',
#  'wii',
#  '#qagb',
#  'inline',
#  'walked',
#  'fair',
#  'itself',
#  'fucking',
#  'davis',
#  'cocky',
#  '#macallan',
#  '#igottagetit',
#  'yorkers',
#  'gentlemen',
#  'independentie',
#  'likability',
#  '#dowtimebetweensessions',
#  'applethe',
#  'widgets',
#  'giddy',
#  '#sxsw-sters',
#  'least',
#  'title',
#  'pop-store',
#  'bus',
#  'died',
#  'login',
#  'lanar',
#  'maps',
#  'do-it-yourself',
#  'disease',
#  'chrome',
#  'downside',
#  'hooking',
#  'hashtags',
#  'andrew',
#  'superseded',
#  'spanking',
#  'ritas',
#  'bigger',
#  'member',
#  'equates',
#  '#shared',
#  'listen',
#  '#cmsxsw',
#  'shocked',
#  '#ws',
#  'bowl',
#  'screen',
#  '#check-in',
#  'dollars',
#  'scarbrough',
#  'reminds',
#  '#sxswacc',
#  'planned',
#  'austinl',
#  'travel',
#  'body',
#  'growing',
#  'medium',
#  'belies',
#  'journalsim',
#  'closed',
#  '#entrepreneur',
#  'masses',
#  'ser',
#  'rtnxpff',
#  'managing',
#  'broadfeed',
#  'contextual',
#  '#cheatday',
#  'headlong',
#  'woah',
#  '#mobilenews',
#  'officer',
#  'hahaha',
#  'atari',
#  'precedent',
#  'wishful',
#  'steam',
#  'peeked',
#  '#aspengrove',
#  'ipadlook',
#  'css',
#  'mashup',
#  'nicholas',
#  'trustworhy',
#  'revolution',
#  'predict',
#  'tvontheradio',
#  'monopoly',
#  '#sxswmobileapps',
#  'zinio',
#  'sorted',
#  'mejust',
#  'overwhelming',
#  'hordes',
#  'cloudsight',
#  'shall',
#  'studios',
#  '#swesxsw',
#  'beans',
#  'moot',
#  '#appletore',
#  'bands',
#  'browsering',
#  '#sxswinfo',
#  'itll',
#  'homeless',
#  'satanic',
#  'disrupt',
#  'second',
#  'amen',
#  'shes',
#  'emulates',
#  'launchrock',
#  'electric',
#  'balsamic',
#  'wider',
#  'kinect',
#  '#bjdproductions',
#  'sticks',
#  'alone',
#  'brightens',
#  'gig',
#  'effect',
#  'additional',
#  'and',
#  '#bsidesaustin',
#  'previews',
#  'hipsters',
#  'nearing',
#  'locations',
#  'bracket',
#  'visions',
#  'marketshare',
#  'priest',
#  'juicepack',
#  'zms',
#  'phair',
#  'trauma',
#  'mist',
#  '#austinbusiness',
#  'busiest',
#  'nonprofits',
#  'hmmmm',
#  'manor',
#  'disasteriphone',
#  'imac',
#  '#earthhour',
#  'bullying',
#  'openingapple',
#  '#crowley',
#  'button',
#  'joomla',
#  '#notsomuch',
#  'wires',
#  'create',
#  'internets',
#  'josh',
#  'analytics',
#  'abandoned',
#  'lobby',
#  'often',
#  'unequipped',
#  'stood',
#  'worn',
#  'luxury',
#  'ubiquity',
#  'receive',
#  'pacman',
#  'iun',
#  'champ',
#  'of',
#  'channel',
#  'viagra',
#  'ubersoc',
#  'elitebook',
#  'eddy',
#  'garageband',
#  'advice',
#  '#api',
#  'spam',
#  'hated',
#  'plans',
#  'privacy',
#  'temperatures',
#  '#authenticationdesign',
#  'austins',
#  '#geogames',
#  'hotpot',
#  'denim',
#  'test',
#  'williams',
#  '#thecivilwars',
#  '#diller',
#  'meetchu',
#  'stalled',
#  'multichannel',
#  'epicenter',
#  'pats',
#  'raffle',
#  '#payingwithdata',
#  'tracy',
#  'two-factor',
#  'dailygrape',
#  'wwwmycubecom',
#  'fascist',
#  'outs',
#  'helps',
#  'calculation',
#  'access',
#  'ae',
#  'hit',
#  'largest',
#  'discovr',
#  'zeus',
#  'computing',
#  '#designflaws',
#  'buzzcircles',
#  'shawn',
#  '#tabletwars',
#  'discover',
#  'wilting',
#  'bff',
#  'baller',
#  'gearing',
#  'make-shift',
#  'blah',
#  '#aphone',
#  'teamed',
#  'chumps',
#  'bn',
#  'trucks',
#  'beauty',
#  'sighting',
#  '#dgtltribe',
#  'sipping',
#  'peoples',
#  '#socialart',
#  'preferrably',
#  'prefer',
#  'for',
#  'egyptian',
#  'farts',
#  'pushsxsw',
#  'excludes',
#  '#seo',
#  '#amhealth',
#  '#boom',
#  'lugging',
#  '#sxsurrogates',
#  'storymap',
#  '#protip',
#  '#super',
#  '#electricnews',
#  '#genius',
#  '#entry',
#  'non-macbookipad',
#  'al',
#  'critiques',
#  '#morefunpeoplewatching',
#  'unconfirmed',
#  'science',
#  'waited',
#  'cruisin',
#  'handler',
#  'reunion',
#  'baaah',
#  'statesmancom',
#  'pitchforks',
#  'specials',
#  'goers',
#  'distant',
#  'chime',
#  'kingston',
#  'employees',
#  '#film',
#  'mania',
#  'cobra',
#  '#wallstreet',
#  'base',
#  'vamos',
#  'surgery',
#  'focusing',
#  'raging',
#  'webinar',
#  'annoying',
#  'partnership',
#  '#commerce',
#  'competitors',
#  'calvin',
#  '#appcircus',
#  'joke',
#  'demonstrating',
#  'msn',
#  'achievement',
#  'speller',
#  'piss',
#  'e-mail',
#  'fools',
#  'rep',
#  'anti',
#  'leaving',
#  'dance',
#  'felix',
#  'dad',
#  'laptops',
#  'draws',
#  'paper',
#  'barring',
#  'ideally',
#  'enter',
#  'non-endorsement',
#  'cent',
#  'ctr',
#  'statuses',
#  'captain',
#  '#sxswapple',
#  '#zaarly',
#  'fantastico',
#  'enpe',
#  'flav',
#  'dali',
#  'books',
#  'deep',
#  'plus',
#  'diego',
#  'lock',
#  'steals',
#  'maths',
#  'south',
#  'texas',
#  'recently',
#  'cancel',
#  '#teamandroidsxsw',
#  '#hootstats',
#  'workshop',
#  'refreshing',
#  'avoid',
#  'volunteer',
#  'voice',
#  'streetview-like',
#  'standard',
#  'pengen',
#  'chargers',
#  'you',
#  'jon',
#  'snagged',
#  'intermittent',
#  'doc',
#  '#companies',
#  'carefully',
#  '#books',
#  'iphonewii',
#  '#thstreet',
#  'chic',
#  'showcased',
#  'inspiration',
#  '#behance',
#  '#googleplaces',
#  'stringer',
#  '#rancewilemon',
#  'averages',
#  'hill',
#  'combining',
#  'unless',
#  'kiosk',
#  'unplugged',
#  'passport',
#  'open',
#  '#eurorscg',
#  'kweli',
#  'gear',
#  'expecting',
#  'swing',
#  'womans',
#  'thrilled',
#  'salgado',
#  'speakers',
#  'joined',
#  'management',
#  'microsim',
#  'insightful',
#  'tdg',
#  'rocked',
#  'egomaniacs',
#  'brah',
#  'hmmmtaxi',
#  'guys',
#  'reason',
#  '#sxswnl',
#  'barton',
#  'finding',
#  'whom',
#  'eww',
#  'spazmatics',
#  '#tbwasxsw',
#  'image',
#  '#droid',
#  'firewall',
#  '#iac',
#  '#merissa',
#  'knife',
#  'apptrophy',
#  'dvrs',
#  'enchanted',
#  'gourdoughs',
#  'fucker',
#  '#periscope',
#  'rotational',
#  'judging',
#  'loyalty',
#  'sitbyus',
#  'reminder',
#  'sf',
#  '#lovemusicapi',
#  'hooks',
#  'consumerization',
#  'leider',
#  'obsolete',
#  'havnt',
#  'buffalo',
#  'claims',
#  'forests',
#  'better',
#  'coursemaybe',
#  '#ogilvy',
#  'jackie',
#  'zap',
#  '#thefutureismobile',
#  'muffins',
#  'hitlantiscom',
#  '#hbs',
#  'mavis',
#  'heading',
#  'elapsed',
#  'ughhhapple',
#  'xoom',
#  'ended',
#  '#usxsw',
#  'monthly',
#  'contradicting',
#  'analogy',
#  'donation',
#  'enhancements',
#  'complained',
#  '#geekery',
#  'schedorg',
#  'sucks',
#  'lemonade',
#  'shoes',
#  'perks',
#  'awards',
#  'furby',
#  '#msusxsw',
#  'tummy',
#  'than',
#  'scene',
#  '):',
#  'ghost',
#  'sisyphus',
#  'pit',
#  'memory',
#  'goona',
#  'healthcare',
#  '#notmycollegesxsw',
#  '#monksofinvention',
#  'adventure',
#  'were',
#  'includes',
#  'ummm',
#  'tech-nerds',
#  'chair',
#  'start',
#  '#sxswbusy',
#  'whiskey',
#  'lonelyboy',
#  'cover',
#  'lovin',
#  'letting',
#  '#sq',
#  'funnels',
#  '#gpp',
#  'dollar',
#  'inc',
#  '#netflixiphone',
#  '#social',
#  'era',
#  'plugin',
#  'aligned',
#  'there',
#  'yourmom',
#  'technology',
#  'protection',
#  '#musedchat',
#  'survived',
#  'travels',
#  'lengthy',
#  'name',
#  'tripping',
#  'replace',
#  'direkova',
#  'ny',
#  '#tsunami',
#  'apture',
#  'ray',
#  'heavythis',
#  'orange',
#  'throttled',
#  'nifty',
#  'booyah',
#  'wants',
#  'sending',
#  '#couch',
#  'preferences',
#  'recs',
#  'prepare',
#  'tristan',
#  'location',
#  '#androids',
#  'whether',
#  'finder',
#  'fanboys',
#  '#cbs',
#  'sluggish',
#  'mood',
#  'believe',
#  'software',
#  'armadillo',
#  'stunt',
#  'family',
#  '#thankyoueconomy',
#  'gee',
#  'chokes',
#  'functions',
#  'clocks',
#  'penalty',
#  'aaron',
#  'restored',
#  'players',
#  'equity',
#  'google-savvy',
#  'tvs',
#  'hardware',
#  'first-generation',
#  'questions',
#  'cowboy',
#  'heute',
#  '#poppop',
#  'console',
#  'magical',
#  'gs',
#  'downtown',
#  'austinjs',
#  'fara',
#  'listings',
#  'named',
#  'apac',
#  'typing',
#  'taste',
#  'translates',
#  'succeed',
#  'documentary',
#  'messed',
#  'pg',
#  'richard',
#  'appreciated',
#  'roadie',
#  'glut',
#  'elements',
#  'doofusness',
#  'aps',
#  'jetpacks',
#  'nfl',
#  'bounds',
#  'brush',
#  'stand',
#  'leisurely',
#  '#smtravel',
#  'essentially',
#  'signup',
#  '#tmobile',
#  'disgrace',
#  '#bummer',
#  '#sxswbigbrands',
#  'wknd',
#  '#smartthings',
#  'crafty',
#  '#gamelayer',
#  'positive',
#  'desk',
#  '#android',
#  'yourselvesseems',
#  'telling',
#  '#engage',
#  'irish',
#  'anoth',
#  'parking',
#  '#startups',
#  '#sqchat',
#  'lazers',
#  'lug',
#  'parakeets',
#  'frazier',
#  'closely',
#  'biomimicry',
#  'gambino',
#  '#incase',
#  'society',
#  '#japanquake',
#  'disgusted',
#  ...]

# %%
corpus_tokens.sort()

# %%
corpus_tokens[1100:1500]
# Out:
# ['#sxsw-influence',
#  '#sxsw-sters',
#  '#sxswa',
#  '#sxswacc',
#  '#sxswaccel',
#  '#sxswadobemobile',
#  '#sxswand',
#  '#sxswapis',
#  '#sxswapple',
#  '#sxswaustin',
#  '#sxswbarcrawl',
#  '#sxswbigbrands',
#  '#sxswbuffalo',
#  '#sxswbusy',
#  '#sxswcares',
#  '#sxswcc',
#  '#sxswcedar',
#  '#sxswcheers',
#  '#sxswchevy',
#  '#sxswchi',
#  '#sxswdad',
#  '#sxswedu',
#  '#sxsweisner',
#  '#sxswengadget',
#  '#sxswers',
#  '#sxswfail',
#  '#sxswfilm',
#  '#sxswgo',
#  '#sxswgood',
#  '#sxswgroup-texting',
#  '#sxswgsdm',
#  '#sxswh',
#  '#sxswhilton',
#  '#sxswhomo',
#  '#sxswhyatt',
#  '#sxswi',
#  '#sxswiaustin',
#  '#sxswic',
#  '#sxswinfo',
#  '#sxswipad',
#  '#sxswis',
#  '#sxswjapan',
#  '#sxswjp',
#  '#sxswk',
#  '#sxswlatam',
#  '#sxswlib',
#  '#sxswlots',
#  '#sxswlustre',
#  '#sxswmaggie',
#  '#sxswmobileapps',
#  '#sxswmonster',
#  '#sxswmoot',
#  '#sxswmusic',
#  '#sxswmymistake',
#  '#sxswnfc',
#  '#sxswnice',
#  '#sxswnikon',
#  '#sxswnl',
#  '#sxswnot',
#  '#sxswnui',
#  '#sxswparty',
#  '#sxswpass',
#  '#sxswprsa',
#  '#sxswpure',
#  '#sxsws',
#  '#sxswsa',
#  '#sxswsaying',
#  '#sxswsix',
#  '#sxswsocial',
#  '#sxswsounds',
#  '#sxswspeakeasy',
#  '#sxswsurvival',
#  '#sxswsxsw',
#  '#sxswthe',
#  '#sxswtoolkit',
#  '#sxswupdates',
#  '#sxswvenue',
#  '#sxswwill',
#  '#sxtxstate',
#  '#sxwonderful',
#  '#sxwsi',
#  '#sydney',
#  '#tablet',
#  '#tablets',
#  '#tabletwars',
#  '#taccsxsw',
#  '#takeonefortheteam',
#  '#takingback',
#  '#taplynx',
#  '#tapworthy',
#  '#tattoo',
#  '#tbwasxsw',
#  '#tc',
#  '#tcsdw',
#  '#teamandroid',
#  '#teamandroidsxsw',
#  '#tech',
#  '#techcrunch',
#  '#techenvy',
#  '#techgeek',
#  '#techgood',
#  '#techi',
#  '#techiesunite',
#  '#technews',
#  '#technology',
#  '#technopriest',
#  '#techrockstar',
#  '#techsmith',
#  '#teletubbie',
#  '#telework',
#  '#telling',
#  '#tempted',
#  '#texas',
#  '#texasevery',
#  '#texting',
#  '#thankgod',
#  '#thanks',
#  '#thanksforthebrandedshades',
#  '#thankyou',
#  '#thankyouecon',
#  '#thankyoueconomy',
#  '#thecivilwars',
#  '#thedaily',
#  '#thefutureismobile',
#  '#thegame',
#  '#thegogame',
#  '#theindustryparty',
#  '#theinternet',
#  '#theplatform',
#  '#therocksreport',
#  '#thestreet',
#  '#thethankyoueconomy',
#  '#thingsthatdontgotogether',
#  '#thinmints',
#  '#thisiscrazyfun',
#  '#thisisdare',
#  '#thstreet',
#  '#tigerblood',
#  '#timoreilly',
#  '#tmobile',
#  '#tmsxsw',
#  '#tnw',
#  '#to',
#  '#tokii',
#  '#tonchidot',
#  '#toocoolforsxswanyway',
#  '#toodamnlucky',
#  '#toolongforme',
#  '#topnews',
#  '#touchingstories',
#  '#toyjoybuy',
#  '#tradeshow',
#  '#transitapps',
#  '#travel',
#  '#travellerarlaunch',
#  '#trending',
#  '#trollfoot',
#  '#tronloungesxsw',
#  '#truestory',
#  '#tsunami',
#  '#tsxsw',
#  '#tveverywhere',
#  '#tweetaholic',
#  '#tweetanonymous',
#  '#tweethouse',
#  '#tweetignite',
#  '#tweets',
#  '#twig',
#  '#twit',
#  '#twitpict',
#  '#twitter',
#  '#twitterpower',
#  '#twnp',
#  '#tx',
#  '#tye',
#  '#tyson',
#  '#ubersocial',
#  '#ucpress',
#  '#ui',
#  '#ui-fail',
#  '#umassjour',
#  '#uncategorized',
#  '#understandinghumans',
#  '#unsix',
#  '#uosxsw',
#  '#up',
#  '#urbanmyth',
#  '#us',
#  '#usa',
#  '#usdes',
#  '#uselessobservations',
#  '#usguys',
#  '#usxsw',
#  '#ux',
#  '#uxamandroid',
#  '#uxdes',
#  '#values',
#  '#vb',
#  '#vbapple',
#  '#vc',
#  '#vcards',
#  '#vegas',
#  '#veriphone',
#  '#verizon',
#  '#verizonftw',
#  '#veryslow',
#  '#vets',
#  '#video',
#  '#videogame',
#  '#videogames',
#  '#videos',
#  '#view',
#  '#vimeo',
#  '#vip',
#  '#viral',
#  '#virgin',
#  '#virtualoffice',
#  '#virtualwallet',
#  '#vitalscom',
#  '#viztalk',
#  '#vizthink',
#  '#vmware',
#  '#voicefeed',
#  '#vom',
#  '#vufinders',
#  '#vzw',
#  '#wack',
#  '#wahoos',
#  '#wakenbake',
#  '#wakeuplaughing',
#  '#wallstreet',
#  '#wam',
#  '#want',
#  '#wantlet',
#  '#wasteoftimeatsxsw',
#  '#weak',
#  '#web',
#  '#webmobile',
#  '#webos',
#  '#webpronews',
#  '#webvisions',
#  '#wedig',
#  '#weekend',
#  '#welivehere',
#  '#wellplayed',
#  '#wepartyhere',
#  '#werdorks',
#  '#what',
#  '#whetherapple',
#  '#whowillrise',
#  '#widfy',
#  '#wiiings',
#  '#willpay',
#  '#win',
#  '#windowsmobile',
#  '#windowsphone',
#  '#winning',
#  '#winwin',
#  '#wireless',
#  '#wisconsin',
#  '#wjchat',
#  '#womenintech',
#  '#woohoo',
#  '#woops',
#  '#wordnerd',
#  '#wordpress',
#  '#workinprogress',
#  '#worklifeprogress',
#  '#wow',
#  '#wp',
#  '#wpdev',
#  '#ws',
#  '#wssxsw',
#  '#wth',
#  '#wwsxsw',
#  '#xm',
#  '#xoom',
#  '#xperiaplay',
#  '#xplat',
#  '#yam',
#  '#yelp',
#  '#youareinteractive',
#  '#youkidshavefun',
#  '#youneedthis',
#  '#yourmom',
#  '#yum',
#  '#zaarly',
#  '#zaarlyiscoming',
#  '#zappos',
#  '#zazzle',
#  '#zazzlesxsw',
#  '#zazzlsxsw',
#  '#zing',
#  '#zlf',
#  '#zomb',
#  '(',
#  '(-:',
#  '(:',
#  ')',
#  '):',
#  '-',
#  '/',
#  ':',
#  ':(',
#  ':)',
#  ':-(',
#  ':-)',
#  ':-/',
#  ':-:',
#  ':-\\',
#  ':-d',
#  ':/',
#  '::',
#  ':]',
#  ':d',
#  ':p',
#  ';',
#  ';)',
#  ';-)',
#  ';]',
#  ';p',
#  '=',
#  '=)',
#  '=d',
#  '\\',
#  ']',
#  ']:',
#  'a',
#  'a-ma-zing',
#  'aapl',
#  'aaron',
#  'ab',
#  'abacus',
#  'abandoned',
#  'abba',
#  'abc',
#  'aber',
#  'ability',
#  'able',
#  'abnormal',
#  'abound',
#  'about',
#  'above',
#  'absolute',
#  'absolutely',
#  'absolutley',
#  'abt',
#  'abuzz',
#  'academy',
#  'acc',
#  'accelerater',
#  'accept',
#  'acceptable',
#  'access',
#  'accessibility',
#  'accessible',
#  'accessories',
#  'accessory',
#  'accidentally',
#  'accommodate',
#  'accompanied',
#  'accomplish',
#  'according',
#  'account',
#  'accounts',
#  'accuracy',
#  'acerbic',
#  'achieve',
#  'achievement',
#  'acknowledge',
#  'ackward',
#  'aclu',
#  'acludont',
#  'aclugoogle',
#  'aclus',
#  'acoustic',
#  'acquired',
#  'acquisition',
#  'across',
#  'acrosse',
#  'act',
#  'acting',
#  'action',
#  'actionable',
#  'actions',
#  'activate',
#  'activations',
#  'activity',
#  'acts',
#  'actsofsharingcom',
#  'actual',
#  'actually',
#  'ad',
#  'adam',
#  'adams',
#  'adapt',
#  'adapters',
#  'adapting',
#  'adaptive',
#  'add']

# %%
len(corpus_tokens)
# Out:
# 9907
